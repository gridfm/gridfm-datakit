# %%
28643.69-range*28643 = min
1-range  = min/28643
range = 1-min/28643
# Out:
#   Cell In[14], line 1
#     28643.69-range*28643 = min
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# load all csv file in the current directory
import os
import pandas as pd

# print 1-min/max of all the csv files
for file in os.listdir('.'):
    if file.endswith('.csv'):
        df = pd.read_csv(file)
        print(file.split('.')[0], (1-df.min()/df.max()).values[0])
# Out:
# ercot_load_act_hr_2024_north_central 0.6928691799136214
# ercot_load_act_hr_2024_south_central 0.7210685510471551
# default 0.5650672468660716
# ercot_load_act_hr_2024_north 0.696655730326432
# ercot_load_act_hr_2024_southern 0.7599330636036152
# ercot_load_act_hr_2024_far_west 0.6900550683016942
# ercot_load_act_hr_2024_east 0.7731957407996384
# ercot_load_act_hr_2024_west 0.73375816729854
# ercot_load_act_hr_2024_coast 0.8386751434785067
# ercot_load_act_hr_2024_total 0.6709588289884417

# %%
df.min() = (1- range) * df.max()
